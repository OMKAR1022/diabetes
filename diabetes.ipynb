# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
db = pd.read_csv('diabetes_dataset-2.csv')

# %%
db.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
db.shape
# Out:
# (768, 9)

# %% [markdown]
# # checking for missing value

# %%
sns.heatmap(db.isnull())
# Out:
# <Axes: >

# %%
plt.plot(db)
plt.show()

# %% [markdown]
# # 0- for non- Diabetes
# # 1- for Diabetes

# %%
scalar = StandardScaler()

# %%
scalar.fit(x)
# Out:
# StandardScaler()

# %%
sd = scalar.transform(x)

# %%
x = db.drop(['Outcome'], axis = 1)
y = db.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
classifier  = svm.SVC(kernel='linear')

# %% [markdown]
# # Train the model

# %%
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
x_train_prediction = classifier.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction ,y_train)

# %%
print("Accuracy score of traning data : " , training_data_accuracy)
# Out:
# Accuracy score of traning data :  0.7654723127035831

# %%
x_test_prediction = classifier.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction ,y_test)

# %%
print("Accuracy score of traning data : " , test_data_accuracy)
# Out:
# Accuracy score of traning data :  0.8181818181818182

# %%
joblib.dump(rf, 'mod_joblib.pkl')
# Out:
# ['mod_joblib.pkl']

# %%
classifier.predict([[3,120,70,20,79,20,0.47,33]])
# Out:
# /Users/omkar/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0])

# %%
joblib.dump(rf, 'model_joblib.pkl')
# Out:
# ['model_joblib.pkl']
